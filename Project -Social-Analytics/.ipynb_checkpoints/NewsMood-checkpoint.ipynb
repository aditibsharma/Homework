# %% [markdown]
# ## Performing a sentiment analysis for Twitter activity of various news oulets, and presenting findings visually.

# %%
# Dependencies
import tweepy
import json
import numpy as np
import matplotlib.pyplot as plt
import requests as requests
import pandas as pd
import seaborn as sns
import csv
import time

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys

consumer_key = "mymEkFlYejolPocBMz1g1CCau"
consumer_secret = "DgPAuuvCG6Ti4dDQIJSiFbZBH8xOqvYyT3VHM4GWfFCCUGwiZa"
access_token = "17875254-tVtAYqQ1hA8ctMUCgDINRGiPyqt16GffN7MKowAkS"
access_token_secret = "pZekN6xoG3A27MujjSmRishSSEJfa0EFRfDEYPfYiaX67"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Search Term

# Target User Accounts
target_user = ("@BBCWorld","@CBSNews", "@CNN", "@FoxNews", "@nytimes")

# Counter
counter = 1
sentiments = []

# Add List to hold sentiment
compound_list = []
positive_list = []
negative_list = []
neutral_list = []
target_user_list =[]

#Increment target user
for user in target_user:
    counter = 0
    
# Loop through 5 pages of tweets (total 100 tweets)
    #for x in range(5):

   # Grab 100 tweets
    public_tweets = api.search(target_term, count=100, result_type="recent")

    # Loop through all tweets 
    for tweet in public_tweets["statuses"]:

#  Run Vader Analysis on each tweet
    # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter

# Add each value to the appropriate array
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        target_user_list.append(user)

# Add sentiments for each tweet into an array
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                          "target_user": user})

# Add to counter 
        counter = counter + 1

# %%
# Print the Sentiments
print(sentiments)
print("")
# Out:
# [{'Date': 'Wed Mar 07 05:30:52 +0000 2018', 'Compound': -0.4215, 'Positive': 0.0, 'Negative': 0.811, 'Neutral': 0.189, 'Tweets Ago': 0, 'target_user': '@BBCWorld'}, {'Date': 'Wed Mar 07 05:30:46 +0000 2018', 'Compound': -0.4215, 'Positive': 0.0, 'Negative': 0.811, 'Neutral': 0.189, 'Tweets Ago': 1, 'target_user': '@BBCWorld'}, {'Date': 'Wed Mar 07 05:30:42 +0000 2018', 'Compound': 0.4939, 'Positive': 0.262, 'Negative': 0.738, 'Neutral': 0.0, 'Tweets Ago': 2, 'target_user': '@BBCWorld'}, {'Date': 'Wed Mar 07 05:30:39 +0000 2018', 'Compound': 0.0, 'Positive': 0.0, 'Negative': 1.0, 'Neutral': 0.0, 'Tweets Ago': 3, 'target_user': '@BBCWorld'}, {'Date': 'Wed Mar 07 05:30:38 +0000 2018', 'Compound': -0.4215, 'Positive': 0.0, 'Negative': 0.811, 'Neutral': 0.189, 'Tweets Ago': 4, 'target_user': '@BBCWorld'}, {'Date': 'Wed Mar 07 05:30:35 +0000 2018', 'Compound': -0.8591, 'Positive': 0.0, 'Negative': 0.457, 'Neutral': 0.543, 'Tweets Ago': 5, 'target_user': '@BBCWorld'}, {'Date': 'Wed Mar 07 0
# ...

# %%
# Convert sentiments to DataFrame
sentiments_df = pd.DataFrame.from_dict(sentiments)
sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.4215  Wed Mar 07 05:30:52 +0000 2018     0.811    0.189     0.000
# 1   -0.4215  Wed Mar 07 05:30:46 +0000 2018     0.811    0.189     0.000
# 2    0.4939  Wed Mar 07 05:30:42 +0000 2018     0.738    0.000     0.262
# 3    0.0000  Wed Mar 07 05:30:39 +0000 2018     1.000    0.000     0.000
# 4   -0.4215  Wed Mar 07 05:30:38 +0000 2018     0.811    0.189     0.000
#
#    Tweets Ago target_user
# 0           0   @BBCWorld
# 1           1   @BBCWorld
# 2           2   @BBCWorld
# 3           3   @BBCWorld
# 4           4   @BBCWorld

# %%
BBCWorld = sentiments_df[(sentiments_df.target_user == "@BBCWorld")]
CBSNews = sentiments_df[(sentiments_df.target_user == "@CBSNews")]
CNN = sentiments_df[(sentiments_df.target_user == "@CNN")]
FoxNews = sentiments_df[(sentiments_df.target_user == "@FoxNews")]
NYTimes = sentiments_df[(sentiments_df.target_user == "@nytimes")]


# Build the scatter plots for each news channel
plt.scatter(BBCWorld['Tweets Ago'], 
            BBCWorld['Compound'], 
            s=100, c=["skyblue"], 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="BBCWorld")

plt.scatter(CBSNews['Tweets Ago'], 
            CBSNews['Compound'], 
            s=100, c=["green"], 
            edgecolor="black", marker="o", 
            alpha=0.8, label="CBSNews")

plt.scatter(CNN['Tweets Ago'], 
            CNN['Compound'], 
            s=100, c=["red"], 
            edgecolor="black", marker="o", 
            alpha=0.8, label="CNN")

plt.scatter(FoxNews['Tweets Ago'], 
            FoxNews['Compound'], 
            s=100, c=["blue"], 
            edgecolor="black", marker="o", 
            alpha=0.8, label="FoxNews")

plt.scatter(NYTimes['Tweets Ago'], 
            NYTimes['Compound'], 
            s=100, c=['gold'], 
            edgecolor="black", marker="o", 
            alpha=0.8, label="NYTimes")

# Incorporate the other graph properties
plt.title("Sentiment Analysis of Media Tweets (03/06/18)")
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.xlim((0,40))
plt.grid(True)

# Create a legend
lgnd = plt.legend(fontsize="medium", mode="Expanded", 
                  numpoints=1, scatterpoints=1, 
                  loc="best", title="Media Sources", 
                  labelspacing=0.5)
#lgnd.legendHandles[0]._sizes = [30]
#lgnd.legendHandles[1]._sizes = [30]
#lgnd.legendHandles[2]._sizes = [30]

# Plot field size
plt.xlim(-5, counter + 5)
plt.ylim(-1.25, 1.25)

# Incorporate a text label regarding circle size
#plt.text(42, 35, "Note:\nCircle size correlates with driver count per city.")

# Save Figure
#plt.savefig("analysis/Fig1.png")

# Show plot
plt.show()
